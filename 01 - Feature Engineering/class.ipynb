# %%
import pandas as pd
pd.set_option('display.precision', 2)
df = pd.read_csv('machine_params_and_cost_v2.csv')
# Out:
#             T1        V1       A1       P1       B1       T2        V2  \
# count  1960.00  1.96e+03  1964.00  1967.00  1969.00  1963.00  1.96e+03
# mean     99.10  4.14e+05   160.66    30.93   121.62   516.63  2.14e+06
# std      39.51  1.76e+05   103.91    17.62    32.54    83.54  1.25e+06
# min      -5.89  1.13e+05    -4.79   -19.05    27.41   286.76  2.72e+05
# 25%      74.86  2.98e+05    82.94    18.92   101.40   465.70  1.22e+06
# 50%      97.08  3.85e+05   155.88    30.11   119.06   513.71  1.92e+06
# 75%     119.68  5.07e+05   230.08    41.58   139.35   561.65  2.85e+06
# max     372.29  1.67e+06   909.03   143.61   346.74  1108.91  1.13e+07
#
#             A2       P2       B2  ...       B4  Contamination_Defect  \
# count  1950.00  1955.00  1968.00  ...  1964.00               2000.00
# mean    258.43    70.30   303.35  ...   339.35                  0.03
# std     157.43    23.46    49.19  ...    15.94                  0.17
# ...

# %%
df.describe()
# Out:
#             T1        V1       A1       P1       B1       T2        V2  \
# count  1960.00  1.96e+03  1964.00  1967.00  1969.00  1963.00  1.96e+03
# mean     99.10  4.14e+05   160.66    30.93   121.62   516.63  2.14e+06
# std      39.51  1.76e+05   103.91    17.62    32.54    83.54  1.25e+06
# min      -5.89  1.13e+05    -4.79   -19.05    27.41   286.76  2.72e+05
# 25%      74.86  2.98e+05    82.94    18.92   101.40   465.70  1.22e+06
# 50%      97.08  3.85e+05   155.88    30.11   119.06   513.71  1.92e+06
# 75%     119.68  5.07e+05   230.08    41.58   139.35   561.65  2.85e+06
# max     372.29  1.67e+06   909.03   143.61   346.74  1108.91  1.13e+07
#
#             A2       P2       B2  ...       B4  Contamination_Defect  \
# count  1950.00  1955.00  1968.00  ...  1964.00               2000.00
# mean    258.43    70.30   303.35  ...   339.35                  0.03
# std     157.43    23.46    49.19  ...    15.94                  0.17
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 31 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   ag                     2000 non-null   object
#  1   bg                     2000 non-null   object
#  2   T1                     1960 non-null   float64
#  3   V1                     1965 non-null   float64
#  4   A1                     1964 non-null   float64
#  5   P1                     1967 non-null   float64
#  6   B1                     1969 non-null   float64
#  7   T2                     1963 non-null   float64
#  8   V2                     1965 non-null   float64
#  9   A2                     1950 non-null   float64
#  10  P2                     1955 non-null   float64
#  11  B2                     1968 non-null   float64
#  12  T3                     1960 non-null   float64
#  13  V3                     1967 non-null   float64
# ...

# %%
def count_ordinal(df, feature):
    count = df.value_counts(feature)
    count.plot(kind='bar')

# %%
count_ordinal(df, 'ag')

# %%
count_ordinal(df, 'bg')

# %%
import seaborn as sns
def count_ordinal_sns(df, feature):
    sns.countplot(data=df, y=feature)

# %%
count_ordinal_sns(df, 'ag')

# %%
count_ordinal_sns(df, 'bg')

# %%
import numpy as np
df_nan = df.replace('<missing>', np.nan, inplace=False)

# %%
count_ordinal_sns(df_nan, 'ag')

# %%
count_ordinal_sns(df_nan, 'bg')

# %%
df_nan.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 31 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   ag                     1978 non-null   object
#  1   bg                     1980 non-null   object
#  2   T1                     1960 non-null   float64
#  3   V1                     1965 non-null   float64
#  4   A1                     1964 non-null   float64
#  5   P1                     1967 non-null   float64
#  6   B1                     1969 non-null   float64
#  7   T2                     1963 non-null   float64
#  8   V2                     1965 non-null   float64
#  9   A2                     1950 non-null   float64
#  10  P2                     1955 non-null   float64
#  11  B2                     1968 non-null   float64
#  12  T3                     1960 non-null   float64
#  13  V3                     1967 non-null   float64
# ...

# %%
df_nan.drop(columns='ID')
df_nan.describe()
# Out:
#             T1        V1       A1       P1       B1       T2        V2  \
# count  1960.00  1.96e+03  1964.00  1967.00  1969.00  1963.00  1.96e+03
# mean     99.10  4.14e+05   160.66    30.93   121.62   516.63  2.14e+06
# std      39.51  1.76e+05   103.91    17.62    32.54    83.54  1.25e+06
# min      -5.89  1.13e+05    -4.79   -19.05    27.41   286.76  2.72e+05
# 25%      74.86  2.98e+05    82.94    18.92   101.40   465.70  1.22e+06
# 50%      97.08  3.85e+05   155.88    30.11   119.06   513.71  1.92e+06
# 75%     119.68  5.07e+05   230.08    41.58   139.35   561.65  2.85e+06
# max     372.29  1.67e+06   909.03   143.61   346.74  1108.91  1.13e+07
#
#             A2       P2       B2  ...       B4  Contamination_Defect  \
# count  1950.00  1955.00  1968.00  ...  1964.00               2000.00
# mean    258.43    70.30   303.35  ...   339.35                  0.03
# std     157.43    23.46    49.19  ...    15.94                  0.17
# ...

# %%
import missingno as mn

mn.matrix(df_nan)
# Out:
# <AxesSubplot:>

# %%
mn.bar(df_nan)
# Out:
# <AxesSubplot:>

# %%
mn.heatmap(df_nan)
# Out:
# <AxesSubplot:>

# %%
df_no_nan = df_nan.dropna()
mn.bar(df_no_nan)
# Out:
# <AxesSubplot:>

# %%
pd.plotting.scatter_matrix(df_nan)
# Out:
# array([[<AxesSubplot:xlabel='T1', ylabel='T1'>,
#         <AxesSubplot:xlabel='V1', ylabel='T1'>,
#         <AxesSubplot:xlabel='A1', ylabel='T1'>,
#         <AxesSubplot:xlabel='P1', ylabel='T1'>,
#         <AxesSubplot:xlabel='B1', ylabel='T1'>,
#         <AxesSubplot:xlabel='T2', ylabel='T1'>,
#         <AxesSubplot:xlabel='V2', ylabel='T1'>,
#         <AxesSubplot:xlabel='A2', ylabel='T1'>,
#         <AxesSubplot:xlabel='P2', ylabel='T1'>,
#         <AxesSubplot:xlabel='B2', ylabel='T1'>,
#         <AxesSubplot:xlabel='T3', ylabel='T1'>,
#         <AxesSubplot:xlabel='V3', ylabel='T1'>,
#         <AxesSubplot:xlabel='A3', ylabel='T1'>,
#         <AxesSubplot:xlabel='P3', ylabel='T1'>,
#         <AxesSubplot:xlabel='B3', ylabel='T1'>,
#         <AxesSubplot:xlabel='T4', ylabel='T1'>,
#         <AxesSubplot:xlabel='V4', ylabel='T1'>,
#         <AxesSubplot:xlabel='A4', ylabel='T1'>,
#         <AxesSubplot:xlabel='P4', ylabel='T1'>,
#         <AxesSubplot:xlabel='B4', ylabel='T1'>,
# ...

# %%
features = ['T1', 'A1', 'B1', 'V1']
pd.plotting.scatter_matrix(df_nan[features])
# Out:
# array([[<AxesSubplot:xlabel='T1', ylabel='T1'>,
#         <AxesSubplot:xlabel='A1', ylabel='T1'>,
#         <AxesSubplot:xlabel='B1', ylabel='T1'>,
#         <AxesSubplot:xlabel='V1', ylabel='T1'>],
#        [<AxesSubplot:xlabel='T1', ylabel='A1'>,
#         <AxesSubplot:xlabel='A1', ylabel='A1'>,
#         <AxesSubplot:xlabel='B1', ylabel='A1'>,
#         <AxesSubplot:xlabel='V1', ylabel='A1'>],
#        [<AxesSubplot:xlabel='T1', ylabel='B1'>,
#         <AxesSubplot:xlabel='A1', ylabel='B1'>,
#         <AxesSubplot:xlabel='B1', ylabel='B1'>,
#         <AxesSubplot:xlabel='V1', ylabel='B1'>],
#        [<AxesSubplot:xlabel='T1', ylabel='V1'>,
#         <AxesSubplot:xlabel='A1', ylabel='V1'>,
#         <AxesSubplot:xlabel='B1', ylabel='V1'>,
#         <AxesSubplot:xlabel='V1', ylabel='V1'>]], dtype=object)

# %%
def histogram(df, feature, bins):
    pd.plotting.scatter_matrix(df[[feature]], hist_kwds={'bins':bins})

# %%
histogram(df_nan, 'T1', 20)

# %% [markdown]
# normal distribution

# %%
histogram(df_nan, 'V1', 20)

# %% [markdown]
# lognormal distribution

# %%
histogram(df_nan, 'A1', 20)

# %% [markdown]
# uniform distribution

# %%
def plot_box(df, features):
    sns.boxplot(data=df[features])

# %%
plot_box(df_nan, ['T1', 'T2', 'T3', 'T4'])

# %%
plot_box(df_nan, ['V1', 'V2', 'V3', 'V4'])

# %%
plot_box(df_nan, ['A1', 'A2', 'A3', 'A4'])

# %%
plot_box(df_nan, ['P1', 'P2', 'P3', 'P4'])

# %% [markdown]
# np.percentile can be used to calculate the quartile boxplots

# %%
def plot_violin(df, features):
    sns.violinplot(data=df[features])

# %%
plot_violin(df_nan, ['T1', 'T2', 'T3', 'T4'])

# %%
def outliers_to_nan(df, features=[], n=3):
    df_to_clean = df.copy()
    # print(df_to_clean)
    # print(df_to_clean.std())
    filtered_df = df_to_clean.mask(abs(df_to_clean - df_to_clean.mean()) > n * df_to_clean.std(), np.nan)
    return filtered_df

# %%
df_no_outliers = outliers_to_nan(df_nan)

df_no_outliers
# Out:
# C:\Users\robc\AppData\Local\Temp\ipykernel_9368\2533609675.py:5: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   filtered_df = df_to_clean.mask(abs(df_to_clean - df_to_clean.mean()) > n * df_to_clean.std(), np.nan)
# C:\Users\robc\AppData\Local\Temp\ipykernel_9368\2533609675.py:5: FutureWarning: Automatic reindexing on DataFrame vs Series comparisons is deprecated and will raise ValueError in a future version. Do `left, right = left.align(right, axis=1, copy=False)` before e.g. `left == right`
#   filtered_df = df_to_clean.mask(abs(df_to_clean - df_to_clean.mean()) > n * df_to_clean.std(), np.nan)
#           ag     bg      T1         V1      A1     P1      B1      T2  \
# 0        Low  Argon   93.99  445746.58  299.44  30.67   61.76  660.21
# 1        Low  Argon   57.16  389648.47  275.28  49.96  132.62  502.63
# ...

# %%
df_no_outliers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 31 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   ag                     1978 non-null   object
#  1   bg                     1980 non-null   object
#  2   T1                     1940 non-null   float64
#  3   V1                     1945 non-null   float64
#  4   A1                     1944 non-null   float64
#  5   P1                     1947 non-null   float64
#  6   B1                     1949 non-null   float64
#  7   T2                     1943 non-null   float64
#  8   V2                     1946 non-null   float64
#  9   A2                     1932 non-null   float64
#  10  P2                     1935 non-null   float64
#  11  B2                     1949 non-null   float64
#  12  T3                     1940 non-null   float64
#  13  V3                     1947 non-null   float64
# ...

# %%
histogram(df_no_outliers, 'V1', 20)

# %%
histogram(df_no_outliers, 'A2', 20)

# %%
histogram(df_no_outliers, 'V2', 20)

# %%
histogram(df_no_outliers, 'V3', 20)

# %%
histogram(df_no_outliers, 'V4', 20)

# %%
def impute_nan_values(df, feature, imputation_type='mean'):
    df_imputed = df.copy()
    if imputation_type == 'mean':
        imputation_value = df_imputed[feature].mean()
    elif imputation_type == 'median':
        imputation_value = df_imputed[feature].median()
    else: 
        raise ValueError('Invalid imputation type. Use mean or median')
    df_imputed[feature].fillna(imputation_value, inplace=True)
    return df_imputed

# %%
df_imputed = impute_nan_values(df_nan, 'T1', 'mean')
df_imputed = impute_nan_values(df_imputed, 'T2', 'mean')
df_imputed = impute_nan_values(df_imputed, 'T3', 'mean')
df_imputed = impute_nan_values(df_imputed, 'T4', 'mean')
mn.matrix(df_imputed)
# Out:
# <AxesSubplot:>

# %%
for v in ['m1_cost', 'm2_cost', 'm3_cost', 'm4_cost']:
    df_imputed = impute_nan_values(df_imputed, v, 'mean')
for v in ['V1','V2', 'V3', 'V4', 'A1', 'A2', 'A3', 'A4', 'B1', 'B2', 'B3', 'B4', 'P1', 'P2', 'P3', 'P4']:
    df_imputed = impute_nan_values(df_imputed, v, 'median')
mn.matrix(df_imputed)
# Out:
# <AxesSubplot:>

# %%
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer
imp = IterativeImputer(max_iter=50, random_state=0)
imputed = imp.fit_transform(df_no_outliers.loc[:, 'T1':'m4_cost'])
imputed
# Out:
# array([[9.39888613e+01, 4.45746580e+05, 2.99436975e+02, ...,
#         2.06462176e+03, 1.15656113e+03, 8.40469242e+02],
#        [5.71618762e+01, 3.89648469e+05, 2.75276163e+02, ...,
#         6.22104301e+03, 8.69714043e+02, 5.23187572e+02],
#        [8.12557094e+01, 3.96609840e+05, 2.35951773e+02, ...,
#         4.00828438e+03, 8.22968657e+02, 6.14949484e+02],
#        ...,
#        [1.10841477e+02, 5.90151683e+05, 2.55159715e+02, ...,
#         2.03642517e+03, 9.12390999e+02, 4.73057867e+02],
#        [4.86128177e+01, 4.10247004e+05, 2.30213514e+02, ...,
#         4.20286098e+03, 1.20868143e+03, 8.21615172e+02],
#        [1.23779047e+02, 1.80230435e+05, 1.64804261e+02, ...,
#         1.51756993e+03, 1.07950148e+03, 8.62817029e+02]])

# %%
num_columns = df.columns[2:-1]
df_imputed = pd.DataFrame(imputed, columns=num_columns)
df_imputed['ag'] = df_no_outliers['ag']
df_imputed['bg'] = df_no_outliers['bg']
mn.matrix(df_imputed)
# Out:
# <AxesSubplot:>

# %%
from sklearn.impute import SimpleImputer
imp = SimpleImputer(strategy='most_frequent')
df_imputed[['ag', 'bg']] = imp.fit_transform(df_imputed[['ag', 'bg']])
mn.matrix(df_imputed)
# Out:
# <AxesSubplot:>

# %%
features_to_be_standardized = num_columns[:-8]
plot_box(df_imputed, features_to_be_standardized)

# %%
from sklearn.preprocessing import StandardScaler
def feature_standardize(df, features_to_standardize):
    scaler = StandardScaler()
    array = scaler.fit_transform(df[features_to_standardize])
    return pd.DataFrame(array, columns=features_to_standardize), scaler.mean_, scaler.scale_
df_scaled, scaler_mean, scaler_scale = feature_standardize(df_imputed, features_to_be_standardized)
plot_box(df_scaled, features_to_be_standardized)
print(scaler_mean)
print(scaler_scale)
# Out:
# [9.70320005e+01 4.04359438e+05 1.54484183e+02 3.00636169e+01
#  1.19812365e+02 5.11911012e+02 2.06813520e+06 2.49944845e+02
#  6.90312175e+01 3.01310490e+02 4.16372906e+02 7.53371987e+05
#  3.39766537e+02 1.61609082e+02 8.16475296e+02 3.51831502e+02
#  4.46270955e+05 5.40301051e+02 2.72992136e+02 3.39382815e+02]
# [3.24394537e+01 1.43685638e+05 8.29906815e+01 1.51985004e+01
#  2.67746664e+01 6.83996162e+01 1.03774934e+06 1.28801810e+02
#  1.94681672e+01 4.19090761e+01 7.55480719e+01 1.40022633e+05
#  1.61671155e+02 8.02842808e+01 8.87800356e+01 4.07077715e+01
#  1.05014453e+05 2.61014756e+02 1.30075157e+02 1.57362044e+01]

# %%
df_scaled[num_columns[-8:]] = df_no_outliers[num_columns[-8:]]
df_scaled[['ag', 'bg']] = df_no_outliers[['ag', 'bg']]

# %%
ag_mapping = {'High': 3, 'Medium': 2, 'Low': 1}
def transform_ordinal_to_numeric(df, feature, mapping_dict):
    df_transformed = df.copy()
    df_transformed[feature] = df_transformed[feature].map(mapping_dict)
    return df_transformed
df_transformed = transform_ordinal_to_numeric(df_scaled, 'ag', ag_mapping)
print(df_transformed['ag'])
# Out:
# 0       1.0
# 1       1.0
# 2       2.0
# 3       2.0
# 4       2.0
#        ...
# 1995    2.0
# 1996    1.0
# 1997    3.0
# 1998    3.0
# 1999    1.0
# Name: ag, Length: 2000, dtype: float64

# %%
df_final = pd.get_dummies(df_transformed, columns=['bg'])
df_final.loc[:, 'bg_Argon':'bg_Neon']
# Out:
#       bg_Argon  bg_C02  bg_Neon
# 0            1       0        0
# 1            1       0        0
# 2            1       0        0
# 3            0       0        1
# 4            1       0        0
# ...        ...     ...      ...
# 1995         1       0        0
# 1996         1       0        0
# 1997         1       0        0
# 1998         0       1        0
# 1999         1       0        0
#
# [2000 rows x 3 columns]

# %%
import matplotlib.pyplot as plt
for column in df_final.columns:
    plt.figure(figsize=(12, 2))
    sns.kdeplot(df_final[column], label=column)
    plt.title(f'KDE Plot for {column}')
    plt.legend()
# Out:
# C:\Users\robc\AppData\Local\Temp\ipykernel_9368\2573106486.py:3: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   plt.figure(figsize=(12, 2))
# c:\Users\robc\anaconda3\envs\CML_2024\lib\site-packages\seaborn\distributions.py:316: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   warnings.warn(msg, UserWarning)
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# c:\Users\robc\anaconda3\envs\CML_2024\lib\site-packages\seaborn\distributions.py:316: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
# ...

# %%
features_to_plot = ['m1_cost', 'm2_cost', 'm3_cost', 'm4_cost']
fig, axes = plt.subplots(nrows=len(features_to_plot),
                         figsize=(12, 2 * len(features_to_plot)), 
                         sharex=True)
for i, column in enumerate(features_to_plot):
    sns.kdeplot(df_final[column], 
                label=column,
                ax=axes[i],
                shade=True,
                color="orange")
axes[i].set_title(f'KDE Plot for {column}')
axes[i].legend()

# %%
plt.figure(figsize=(7, 7))
sns.kdeplot(x=df_final['m4_cost'], 
            y=df_final['m1_cost'], 
            label=column,
            shade=True,
            color='blue')
plt.title(f'KDE Plot for {column}')
plt.legend()
plt.show()

# %% [markdown]
# also
# qq plot
